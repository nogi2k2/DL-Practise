# %%
import os
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import layers, activations, regularizers
from tensorflow.keras.datasets import mnist 
import tensorflow_hub as hub

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable = True)

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32')/255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32')/255.0

# %%
class CNNBlock(layers.Layer):
    def __init__(self, out_channels, kernel_size = 3):
        super(CNNBlock, self).__init__()
        self.conv1 = layers.Conv2D(out_channels, kernel_size, padding = 'same')
        self.bn = layers.BatchNormalization()
        # self.relu = keras.activations.relu
        self.relu = layers.ReLU()
        
    def call(self, input_tensor, training = False):
        x = self.conv1(input_tensor)
        x = self.bn(x, training = training)
        x = self.relu(x)
        return x

# %%
inp = tf.keras.Input(shape = (28,28,1))
conv1 = CNNBlock(32)(inp)
conv2 = CNNBlock(64)(conv1)
conv3 = CNNBlock(128)(conv2)
gap = layers.GlobalAveragePooling2D()(conv3) # Produces (batch_size, 128)
# flatten = layers.Flatten()(conv3) (Would produce (batch_size, H*W*128))
dense1 = layers.Dense(128, activation = 'relu')(gap)
dense2 = layers.Dense(10)(dense1)

model = Model(inputs = [inp], outputs = [dense2])
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  cnn_block_1 (CNNBlock)      (None, 28, 28, 32)        448
#
#  cnn_block_2 (CNNBlock)      (None, 28, 28, 64)        18752
#
#  cnn_block_3 (CNNBlock)      (None, 28, 28, 128)       74368
#
#  global_average_pooling2d (G  (None, 128)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 111,370
# Trainable params: 110,922
# Non-trainable params: 448
# _________________________________________________________________
# None

# %%
model.compile(
    loss = keras.losses.SparseCategoricalCrossentropy(from_logits = True),
    optimizer = keras.optimizers.Adam(),
    metrics = ['accuracy']
)

# %%
model.fit(x_train, y_train, batch_size = 64, verbose = 2, epochs = 3)
model.evaluate(x_test, y_test, batch_size = 64, verbose = 2)
# Out:
# Epoch 1/3
# 938/938 - 23s - loss: 0.4543 - accuracy: 0.8724 - 23s/epoch - 24ms/step
# Epoch 2/3
# 938/938 - 16s - loss: 0.1421 - accuracy: 0.9583 - 16s/epoch - 17ms/step
# Epoch 3/3
# 938/938 - 16s - loss: 0.1129 - accuracy: 0.9662 - 16s/epoch - 17ms/step
# 157/157 - 1s - loss: 6.1408 - accuracy: 0.2180 - 1s/epoch - 8ms/step
# [6.140760898590088, 0.21799999475479126]

# %%
model.save('pretrained/BasicCNN/')
model_new = keras.models.load_model("pretrained/BasicCNN/", custom_objects = {'CNNBlock': CNNBlock})
print(model_new.summary())
# Out:
# WARNING:absl:Found untraced functions such as conv2d_1_layer_call_fn, conv2d_1_layer_call_and_return_conditional_losses, _jit_compiled_convolution_op, re_lu_layer_call_fn, re_lu_layer_call_and_return_conditional_losses while saving (showing 5 of 15). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: pretrained/BasicCNN/assets
# INFO:tensorflow:Assets written to: pretrained/BasicCNN/assets
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  cnn_block_1 (CNNBlock)      (None, 28, 28, 32)        448
#
#  cnn_block_2 (CNNBlock)      (None, 28, 28, 64)        18752
#
#  cnn_block_3 (CNNBlock)      (None, 28, 28, 128)       74368
#
#  global_average_pooling2d (G  (None, 128)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 111,370
# Trainable params: 110,922
# Non-trainable params: 448
# _________________________________________________________________
# None

# %%
class ResBlock(layers.Layer):
    def __init__(self, channels):
        super(ResBlock, self).__init__()
        self.conv1 = CNNBlock(channels[0])
        self.conv2 = CNNBlock(channels[1])
        self.conv3 = CNNBlock(channels[2])
        self.pool1 = layers.MaxPooling2D()
        self.identity = layers.Conv2D(channels[1], 1, padding = 'same')

    def call(self, input_tensor, training = False):
        op1 = self.conv1(input_tensor, training = training)
        op2 = self.conv2(op1, training = training)
        op3 = self.conv3(op2 + self.identity(input_tensor), training = training) 
        pool = self.pool1(op3)
        
        return pool

# %%
channels1 = [32, 32, 128]
channels2 = [128, 128, 256]
channels3 = [128, 256, 512]

inp = keras.Input(shape = (28, 28, 1))
res1 = ResBlock(channels1)(inp)
res2 = ResBlock(channels2)(res1)
res3 = ResBlock(channels3)(res2)
gap = layers.GlobalAveragePooling2D()(res3)
# flatten = layers.Flatten(gap)
dense = layers.Dense(10)(gap)

model = Model(inputs = [inp, ], outputs = [dense, ])
print(model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  res_block (ResBlock)        (None, 14, 14, 128)       47392
#
#  res_block_1 (ResBlock)      (None, 7, 7, 256)         608896
#
#  res_block_2 (ResBlock)      (None, 3, 3, 512)         1839744
#
#  global_average_pooling2d_1   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 2,501,162
# Trainable params: 2,497,962
# Non-trainable params: 3,200
# _________________________________________________________________
# None

# %%
model.compile(
    loss = keras.losses.SparseCategoricalCrossentropy(from_logits = True),
    optimizer = keras.optimizers.Adam(),
    metrics = ['accuracy']
)

# %%
model.fit(x_train, y_train, epochs = 1, verbose = 2, batch_size = 64)
model.evaluate(x_test, y_test, verbose = 2, batch_size = 64)
# Out:
# 938/938 - 44s - loss: 0.0864 - accuracy: 0.9745 - 44s/epoch - 47ms/step
# 157/157 - 3s - loss: 0.0605 - accuracy: 0.9808 - 3s/epoch - 19ms/step
# [0.06048215180635452, 0.9807999730110168]

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 28 * 28).astype('float32')/255.0
x_test = x_test.reshape(-1, 28 * 28).astype('float32')/255.0

# %%
class CustomLayer(layers.Layer):
    def __init__(self, output_dim, input_dim):
        super(CustomLayer, self).__init__()
        self.w = self.add_weight(
            name = 'weight-x',
            shape = (input_dim, output_dim),
            initializer = 'random_normal',
            trainable = True,
        )
        self.b = self.add_weight(
            name = 'bias-x',
            shape = (output_dim, ),
            initializer = 'zeros',
            trainable = True,
        )
    def call(self, input_tensor):
        op = tf.matmul(input_tensor, self.w) + self.b
        return op

# %%
class CustomModel(keras.Model):
    def __init__(self, num_classes = 10):
        super(CustomModel, self).__init__()
        self.dense1 = CustomLayer(64, 784)
        self.dense2 = CustomLayer(num_classes, 64)

    def call(self, input_tensor):
        layer1 = tf.nn.relu(self.dense1(input_tensor))
        return self.dense2(layer1)

# %%
model_custom = CustomModel()
model_custom.compile(
    loss = keras.losses.SparseCategoricalCrossentropy(from_logits = True),
    optimizer = keras.optimizers.Adam(),
    metrics = ['accuracy'],
)

model_custom.fit(x_train, y_train, verbose = 2, batch_size = 32, epochs = 1)
model_custom.evaluate(x_test, y_test, verbose = 2, batch_size = 32)
# Out:
# 1875/1875 - 9s - loss: 0.3447 - accuracy: 0.9055 - 9s/epoch - 5ms/step
# 313/313 - 2s - loss: 0.1843 - accuracy: 0.9431 - 2s/epoch - 5ms/step
# [0.18426132202148438, 0.9430999755859375]

# %% [markdown]
# Saving and Loading Model (Serialization of Model - saved as a data structure) and Model weights
#
# Saving the model also saves the:
# 1. Model Weigths
# 2. Model Architecture
# 3. Training Configuration (The configs the model was compiled with)
# 4. Optimizer and states

# %%
# Sequential model saves work only with Sequential and Functional model saves work only with Functional model.

# model.save__weights('saved_model/', save_format = 'h5')
# model = model.load_weights('saved_model/')

# %%
#Saving the entire model with all configs: 
# (Works with Sequential, Functional and Subclassing)

# model.save('entire_saved_model/')
# model = keras.models.load_model('entire_saved_model/')

# %% [markdown]
# Using Pretrained Models and Freeing layers

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32')/255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32')/255.0

# %%
# Using a manually made pretrained model:
model_old = keras.models.load_model('pretrained/BasicCNN/', custom_objects = {'CNNBlock': CNNBlock})
print(model_old.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  cnn_block_1 (CNNBlock)      (None, 28, 28, 32)        448
#
#  cnn_block_2 (CNNBlock)      (None, 28, 28, 64)        18752
#
#  cnn_block_3 (CNNBlock)      (None, 28, 28, 128)       74368
#
#  global_average_pooling2d (G  (None, 128)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 111,370
# Trainable params: 110,922
# Non-trainable params: 448
# _________________________________________________________________
# None

# %%
base_input = model_old.layers[0].input
base_output = model_old.layers[-2].output
classification = layers.Dense(10)(base_output)
model_modified = Model(inputs = [base_input, ], outputs = [classification, ])

for layer in model_modified.layers[:-1]:
    layer.trainable == False

print(model_modified.summary())
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  cnn_block_1 (CNNBlock)      (None, 28, 28, 32)        448
#
#  cnn_block_2 (CNNBlock)      (None, 28, 28, 64)        18752
#
#  cnn_block_3 (CNNBlock)      (None, 28, 28, 128)       74368
#
#  global_average_pooling2d (G  (None, 128)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_4 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 111,370
# Trainable params: 110,922
# Non-trainable params: 448
# _________________________________________________________________
# None

# %%
model_modified.compile(
    loss = keras.losses.SparseCategoricalCrossentropy(from_logits = True),
    optimizer = keras.optimizers.Adam(learning_rate=0.001),
    metrics = ['accuracy'],
)

# %%
model_modified.fit(x_train, y_train, verbose = 2, batch_size = 64, epochs = 5)
model_modified.evaluate(x_test, y_test, batch_size = 64, verbose = 2)
# Out:
# Epoch 1/5
# 938/938 - 17s - loss: 0.2500 - accuracy: 0.9407 - 17s/epoch - 18ms/step
# Epoch 2/5
# 938/938 - 17s - loss: 0.1024 - accuracy: 0.9701 - 17s/epoch - 18ms/step
# Epoch 3/5
# 938/938 - 18s - loss: 0.0873 - accuracy: 0.9743 - 18s/epoch - 19ms/step
# Epoch 4/5
# 938/938 - 16s - loss: 0.0786 - accuracy: 0.9757 - 16s/epoch - 17ms/step
# Epoch 5/5
# 938/938 - 16s - loss: 0.0704 - accuracy: 0.9787 - 16s/epoch - 17ms/step
# 157/157 - 2s - loss: 0.2569 - accuracy: 0.9144 - 2s/epoch - 10ms/step
# [0.2569253742694855, 0.9143999814987183]

# %%
x = tf.random.normal(shape = (5, 299, 299, 3))
y = tf.constant([0, 1, 2, 3, 4])

# %%
#Using keras pretrained models:
inception_v3 = keras.applications.InceptionV3(include_top = False)
inception_v3.trainable = False 
base_input = inception_v3.layers[0].input
base_output = inception_v3.layers[-1].output
gap = layers.GlobalAveragePooling2D()(base_output)
dense1 = layers.Dense(512, activation = 'relu')(gap)
classification_v3 = layers.Dense(5)(dense1)
model_inception = Model(inputs = [base_input, ], outputs = [classification_v3, ])

# for layer in model_inception.layers[:-1]:
#     layer.trainable = False
    
print(model_inception.summary())
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d_204 (Conv2D)            (None, None, None,   864         ['input_6[0][0]']
#                                 32)
#
#  batch_normalization_201 (Batch  (None, None, None,   96         ['conv2d_204[0][0]']
#  Normalization)                 32)
#
#  activation_188 (Activation)    (None, None, None,   0           ['batch_normalization_201[0][0]']
#                                 32)
#
#  conv2d_205 (Conv2D)            (None, None, None,   9216        ['activation_188[0][0]']
#                                 32)
#
#  batch_normalization_202 (Batch  (None, None, None,   96         ['conv2d_205[0][0]']
#  Normalization)                 32)
#
#  activation_189 (Activation)    (None, None, None,   0           ['batch_normalization_202[0][0]']
#                                 32)
#
#  conv2d_206 (Conv2D)            (None, None, None,   18432       ['activation_189[0][0]']
#                                 64)
#
#  batch_normalization_203 (Batch  (None, None, None,   192        ['conv2d_206[0][0]']
#  Normalization)                 64)
#
#  activation_190 (Activation)    (None, None, None,   0           ['batch_normalization_203[0][0]']
#                                 64)
#
#  max_pooling2d_11 (MaxPooling2D  (None, None, None,   0          ['activation_190[0][0]']
#  )                              64)
#
#  conv2d_207 (Conv2D)            (None, None, None,   5120        ['max_pooling2d_11[0][0]']
#                                 80)
#
#  batch_normalization_204 (Batch  (None, None, None,   240        ['conv2d_207[0][0]']
#  Normalization)                 80)
#
#  activation_191 (Activation)    (None, None, None,   0           ['batch_normalization_204[0][0]']
#                                 80)
#
#  conv2d_208 (Conv2D)            (None, None, None,   138240      ['activation_191[0][0]']
#                                 192)
#
#  batch_normalization_205 (Batch  (None, None, None,   576        ['conv2d_208[0][0]']
#  Normalization)                 192)
#
#  activation_192 (Activation)    (None, None, None,   0           ['batch_normalization_205[0][0]']
#                                 192)
#
#  max_pooling2d_12 (MaxPooling2D  (None, None, None,   0          ['activation_192[0][0]']
#  )                              192)
#
#  conv2d_212 (Conv2D)            (None, None, None,   12288       ['max_pooling2d_12[0][0]']
#                                 64)
#
#  batch_normalization_209 (Batch  (None, None, None,   192        ['conv2d_212[0][0]']
#  Normalization)                 64)
#
#  activation_196 (Activation)    (None, None, None,   0           ['batch_normalization_209[0][0]']
#                                 64)
#
#  conv2d_210 (Conv2D)            (None, None, None,   9216        ['max_pooling2d_12[0][0]']
#                                 48)
#
#  conv2d_213 (Conv2D)            (None, None, None,   55296       ['activation_196[0][0]']
#                                 96)
#
#  batch_normalization_207 (Batch  (None, None, None,   144        ['conv2d_210[0][0]']
#  Normalization)                 48)
#
#  batch_normalization_210 (Batch  (None, None, None,   288        ['conv2d_213[0][0]']
#  Normalization)                 96)
#
#  activation_194 (Activation)    (None, None, None,   0           ['batch_normalization_207[0][0]']
#                                 48)
#
#  activation_197 (Activation)    (None, None, None,   0           ['batch_normalization_210[0][0]']
#                                 96)
#
#  average_pooling2d_18 (AverageP  (None, None, None,   0          ['max_pooling2d_12[0][0]']
#  ooling2D)                      192)
#
#  conv2d_209 (Conv2D)            (None, None, None,   12288       ['max_pooling2d_12[0][0]']
#                                 64)
#
#  conv2d_211 (Conv2D)            (None, None, None,   76800       ['activation_194[0][0]']
#                                 64)
#
#  conv2d_214 (Conv2D)            (None, None, None,   82944       ['activation_197[0][0]']
#                                 96)
#
#  conv2d_215 (Conv2D)            (None, None, None,   6144        ['average_pooling2d_18[0][0]']
#                                 32)
#
#  batch_normalization_206 (Batch  (None, None, None,   192        ['conv2d_209[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_208 (Batch  (None, None, None,   192        ['conv2d_211[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_211 (Batch  (None, None, None,   288        ['conv2d_214[0][0]']
#  Normalization)                 96)
#
#  batch_normalization_212 (Batch  (None, None, None,   96         ['conv2d_215[0][0]']
#  Normalization)                 32)
#
#  activation_193 (Activation)    (None, None, None,   0           ['batch_normalization_206[0][0]']
#                                 64)
#
#  activation_195 (Activation)    (None, None, None,   0           ['batch_normalization_208[0][0]']
#                                 64)
#
#  activation_198 (Activation)    (None, None, None,   0           ['batch_normalization_211[0][0]']
#                                 96)
#
#  activation_199 (Activation)    (None, None, None,   0           ['batch_normalization_212[0][0]']
#                                 32)
#
#  mixed0 (Concatenate)           (None, None, None,   0           ['activation_193[0][0]',
#                                 256)                              'activation_195[0][0]',
#                                                                   'activation_198[0][0]',
#                                                                   'activation_199[0][0]']
#
#  conv2d_219 (Conv2D)            (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  batch_normalization_216 (Batch  (None, None, None,   192        ['conv2d_219[0][0]']
#  Normalization)                 64)
#
#  activation_203 (Activation)    (None, None, None,   0           ['batch_normalization_216[0][0]']
#                                 64)
#
#  conv2d_217 (Conv2D)            (None, None, None,   12288       ['mixed0[0][0]']
#                                 48)
#
#  conv2d_220 (Conv2D)            (None, None, None,   55296       ['activation_203[0][0]']
#                                 96)
#
#  batch_normalization_214 (Batch  (None, None, None,   144        ['conv2d_217[0][0]']
#  Normalization)                 48)
#
#  batch_normalization_217 (Batch  (None, None, None,   288        ['conv2d_220[0][0]']
#  Normalization)                 96)
#
#  activation_201 (Activation)    (None, None, None,   0           ['batch_normalization_214[0][0]']
#                                 48)
#
#  activation_204 (Activation)    (None, None, None,   0           ['batch_normalization_217[0][0]']
#                                 96)
#
#  average_pooling2d_19 (AverageP  (None, None, None,   0          ['mixed0[0][0]']
#  ooling2D)                      256)
#
#  conv2d_216 (Conv2D)            (None, None, None,   16384       ['mixed0[0][0]']
#                                 64)
#
#  conv2d_218 (Conv2D)            (None, None, None,   76800       ['activation_201[0][0]']
#                                 64)
#
#  conv2d_221 (Conv2D)            (None, None, None,   82944       ['activation_204[0][0]']
#                                 96)
#
#  conv2d_222 (Conv2D)            (None, None, None,   16384       ['average_pooling2d_19[0][0]']
#                                 64)
#
#  batch_normalization_213 (Batch  (None, None, None,   192        ['conv2d_216[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_215 (Batch  (None, None, None,   192        ['conv2d_218[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_218 (Batch  (None, None, None,   288        ['conv2d_221[0][0]']
#  Normalization)                 96)
#
#  batch_normalization_219 (Batch  (None, None, None,   192        ['conv2d_222[0][0]']
#  Normalization)                 64)
#
#  activation_200 (Activation)    (None, None, None,   0           ['batch_normalization_213[0][0]']
#                                 64)
#
#  activation_202 (Activation)    (None, None, None,   0           ['batch_normalization_215[0][0]']
#                                 64)
#
#  activation_205 (Activation)    (None, None, None,   0           ['batch_normalization_218[0][0]']
#                                 96)
#
#  activation_206 (Activation)    (None, None, None,   0           ['batch_normalization_219[0][0]']
#                                 64)
#
#  mixed1 (Concatenate)           (None, None, None,   0           ['activation_200[0][0]',
#                                 288)                              'activation_202[0][0]',
#                                                                   'activation_205[0][0]',
#                                                                   'activation_206[0][0]']
#
#  conv2d_226 (Conv2D)            (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  batch_normalization_223 (Batch  (None, None, None,   192        ['conv2d_226[0][0]']
#  Normalization)                 64)
#
#  activation_210 (Activation)    (None, None, None,   0           ['batch_normalization_223[0][0]']
#                                 64)
#
#  conv2d_224 (Conv2D)            (None, None, None,   13824       ['mixed1[0][0]']
#                                 48)
#
#  conv2d_227 (Conv2D)            (None, None, None,   55296       ['activation_210[0][0]']
#                                 96)
#
#  batch_normalization_221 (Batch  (None, None, None,   144        ['conv2d_224[0][0]']
#  Normalization)                 48)
#
#  batch_normalization_224 (Batch  (None, None, None,   288        ['conv2d_227[0][0]']
#  Normalization)                 96)
#
#  activation_208 (Activation)    (None, None, None,   0           ['batch_normalization_221[0][0]']
#                                 48)
#
#  activation_211 (Activation)    (None, None, None,   0           ['batch_normalization_224[0][0]']
#                                 96)
#
#  average_pooling2d_20 (AverageP  (None, None, None,   0          ['mixed1[0][0]']
#  ooling2D)                      288)
#
#  conv2d_223 (Conv2D)            (None, None, None,   18432       ['mixed1[0][0]']
#                                 64)
#
#  conv2d_225 (Conv2D)            (None, None, None,   76800       ['activation_208[0][0]']
#                                 64)
#
#  conv2d_228 (Conv2D)            (None, None, None,   82944       ['activation_211[0][0]']
#                                 96)
#
#  conv2d_229 (Conv2D)            (None, None, None,   18432       ['average_pooling2d_20[0][0]']
#                                 64)
#
#  batch_normalization_220 (Batch  (None, None, None,   192        ['conv2d_223[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_222 (Batch  (None, None, None,   192        ['conv2d_225[0][0]']
#  Normalization)                 64)
#
#  batch_normalization_225 (Batch  (None, None, None,   288        ['conv2d_228[0][0]']
#  Normalization)                 96)
#
#  batch_normalization_226 (Batch  (None, None, None,   192        ['conv2d_229[0][0]']
#  Normalization)                 64)
#
#  activation_207 (Activation)    (None, None, None,   0           ['batch_normalization_220[0][0]']
#                                 64)
#
#  activation_209 (Activation)    (None, None, None,   0           ['batch_normalization_222[0][0]']
#                                 64)
#
#  activation_212 (Activation)    (None, None, None,   0           ['batch_normalization_225[0][0]']
#                                 96)
#
#  activation_213 (Activation)    (None, None, None,   0           ['batch_normalization_226[0][0]']
#                                 64)
#
#  mixed2 (Concatenate)           (None, None, None,   0           ['activation_207[0][0]',
#                                 288)                              'activation_209[0][0]',
#                                                                   'activation_212[0][0]',
#                                                                   'activation_213[0][0]']
#
#  conv2d_231 (Conv2D)            (None, None, None,   18432       ['mixed2[0][0]']
#                                 64)
#
#  batch_normalization_228 (Batch  (None, None, None,   192        ['conv2d_231[0][0]']
#  Normalization)                 64)
#
#  activation_215 (Activation)    (None, None, None,   0           ['batch_normalization_228[0][0]']
#                                 64)
#
#  conv2d_232 (Conv2D)            (None, None, None,   55296       ['activation_215[0][0]']
#                                 96)
#
#  batch_normalization_229 (Batch  (None, None, None,   288        ['conv2d_232[0][0]']
#  Normalization)                 96)
#
#  activation_216 (Activation)    (None, None, None,   0           ['batch_normalization_229[0][0]']
#                                 96)
#
#  conv2d_230 (Conv2D)            (None, None, None,   995328      ['mixed2[0][0]']
#                                 384)
#
#  conv2d_233 (Conv2D)            (None, None, None,   82944       ['activation_216[0][0]']
#                                 96)
#
#  batch_normalization_227 (Batch  (None, None, None,   1152       ['conv2d_230[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_230 (Batch  (None, None, None,   288        ['conv2d_233[0][0]']
#  Normalization)                 96)
#
#  activation_214 (Activation)    (None, None, None,   0           ['batch_normalization_227[0][0]']
#                                 384)
#
#  activation_217 (Activation)    (None, None, None,   0           ['batch_normalization_230[0][0]']
#                                 96)
#
#  max_pooling2d_13 (MaxPooling2D  (None, None, None,   0          ['mixed2[0][0]']
#  )                              288)
#
#  mixed3 (Concatenate)           (None, None, None,   0           ['activation_214[0][0]',
#                                 768)                              'activation_217[0][0]',
#                                                                   'max_pooling2d_13[0][0]']
#
#  conv2d_238 (Conv2D)            (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  batch_normalization_235 (Batch  (None, None, None,   384        ['conv2d_238[0][0]']
#  Normalization)                 128)
#
#  activation_222 (Activation)    (None, None, None,   0           ['batch_normalization_235[0][0]']
#                                 128)
#
#  conv2d_239 (Conv2D)            (None, None, None,   114688      ['activation_222[0][0]']
#                                 128)
#
#  batch_normalization_236 (Batch  (None, None, None,   384        ['conv2d_239[0][0]']
#  Normalization)                 128)
#
#  activation_223 (Activation)    (None, None, None,   0           ['batch_normalization_236[0][0]']
#                                 128)
#
#  conv2d_235 (Conv2D)            (None, None, None,   98304       ['mixed3[0][0]']
#                                 128)
#
#  conv2d_240 (Conv2D)            (None, None, None,   114688      ['activation_223[0][0]']
#                                 128)
#
#  batch_normalization_232 (Batch  (None, None, None,   384        ['conv2d_235[0][0]']
#  Normalization)                 128)
#
#  batch_normalization_237 (Batch  (None, None, None,   384        ['conv2d_240[0][0]']
#  Normalization)                 128)
#
#  activation_219 (Activation)    (None, None, None,   0           ['batch_normalization_232[0][0]']
#                                 128)
#
#  activation_224 (Activation)    (None, None, None,   0           ['batch_normalization_237[0][0]']
#                                 128)
#
#  conv2d_236 (Conv2D)            (None, None, None,   114688      ['activation_219[0][0]']
#                                 128)
#
#  conv2d_241 (Conv2D)            (None, None, None,   114688      ['activation_224[0][0]']
#                                 128)
#
#  batch_normalization_233 (Batch  (None, None, None,   384        ['conv2d_236[0][0]']
#  Normalization)                 128)
#
#  batch_normalization_238 (Batch  (None, None, None,   384        ['conv2d_241[0][0]']
#  Normalization)                 128)
#
#  activation_220 (Activation)    (None, None, None,   0           ['batch_normalization_233[0][0]']
#                                 128)
#
#  activation_225 (Activation)    (None, None, None,   0           ['batch_normalization_238[0][0]']
#                                 128)
#
#  average_pooling2d_21 (AverageP  (None, None, None,   0          ['mixed3[0][0]']
#  ooling2D)                      768)
#
#  conv2d_234 (Conv2D)            (None, None, None,   147456      ['mixed3[0][0]']
#                                 192)
#
#  conv2d_237 (Conv2D)            (None, None, None,   172032      ['activation_220[0][0]']
#                                 192)
#
#  conv2d_242 (Conv2D)            (None, None, None,   172032      ['activation_225[0][0]']
#                                 192)
#
#  conv2d_243 (Conv2D)            (None, None, None,   147456      ['average_pooling2d_21[0][0]']
#                                 192)
#
#  batch_normalization_231 (Batch  (None, None, None,   576        ['conv2d_234[0][0]']
#  Normalization)                 192)
#
#  batch_normalization_234 (Batch  (None, None, None,   576        ['conv2d_237[0][0]']
#  Normalization)                 192)
#
#  batch_normalization_239 (Batch  (None, None, None,   576        ['conv2d_242[0][0]']
#  Normalization)                 192)
#
#  batch_normalization_240 (Batch  (None, None, None,   576        ['conv2d_243[0][0]']
#  Normalization)                 192)
#
#  activation_218 (Activation)    (None, None, None,   0           ['batch_normalization_231[0][0]']
#                                 192)
#
#  activation_221 (Activation)    (None, None, None,   0           ['batch_normalization_234[0][0]']
#                                 192)
#
#  activation_226 (Activation)    (None, None, None,   0           ['batch_normalization_239[0][0]']
#                                 192)
#
#  activation_227 (Activation)    (None, None, None,   0           ['batch_normalization_240[0][0]']
#                                 192)
#
#  mixed4 (Concatenate)           (None, None, None,   0           ['activation_218[0][0]',
#                                 768)                              'activation_221[0][0]',
#                                                                   'activation_226[0][0]',
#                                                                   'activation_227[0][0]']
#
#  conv2d_248 (Conv2D)            (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  batch_normalization_245 (Batch  (None, None, None,   480        ['conv2d_248[0][0]']
#  Normalization)                 160)
#
#  activation_232 (Activation)    (None, None, None,   0           ['batch_normalization_245[0][0]']
#                                 160)
#
#  conv2d_249 (Conv2D)            (None, None, None,   179200      ['activation_232[0][0]']
#                                 160)
#
#  batch_normalization_246 (Batch  (None, None, None,   480        ['conv2d_249[0][0]']
#  Normalization)                 160)
#
#  activation_233 (Activation)    (None, None, None,   0           ['batch_normalization_246[0][0]']
#                                 160)
#
#  conv2d_245 (Conv2D)            (None, None, None,   122880      ['mixed4[0][0]']
#                                 160)
#
#  conv2d_250 (Conv2D)            (None, None, None,   179200      ['activation_233[0][0]']
#                                 160)
#
#  batch_normalization_242 (Batch  (None, None, None,   480        ['conv2d_245[0][0]']
#  Normalization)                 160)
#
#  batch_normalization_247 (Batch  (None, None, None,   480        ['conv2d_250[0][0]']
#  Normalization)                 160)
#
#  activation_229 (Activation)    (None, None, None,   0           ['batch_normalization_242[0][0]']
#                                 160)
#
#  activation_234 (Activation)    (None, None, None,   0           ['batch_normalization_247[0][0]']
#                                 160)
#
#  conv2d_246 (Conv2D)            (None, None, None,   179200      ['activation_229[0][0]']
#                                 160)
#
#  conv2d_251 (Conv2D)            (None, None, None,   179200      ['activation_234[0][0]']
#                                 160)
#
#  batch_normalization_243 (Batch  (None, None, None,   480        ['conv2d_246[0][0]']
#  Normalization)                 160)
#
#  batch_normalization_248 (Batch  (None, None, None,   480        ['conv2d_251[0][0]']
#  Normalization)                 160)
#
#  activation_230 (Activation)    (None, None, None,   0           ['batch_normalization_243[0][0]']
#                                 160)
#
#  activation_235 (Activation)    (None, None, None,   0           ['batch_normalization_248[0][0]']
#                                 160)
#
#  average_pooling2d_22 (AverageP  (None, None, None,   0          ['mixed4[0][0]']
#  ooling2D)                      768)
#
#  conv2d_244 (Conv2D)            (None, None, None,   147456      ['mixed4[0][0]']
#                                 192)
#
#  conv2d_247 (Conv2D)            (None, None, None,   215040      ['activation_230[0][0]']
#                                 192)
#
#  conv2d_252 (Conv2D)            (None, None, None,   215040      ['activation_235[0][0]']
#                                 192)
#
#  conv2d_253 (Conv2D)            (None, None, None,   147456      ['average_pooling2d_22[0][0]']
#                                 192)
#
#  batch_normalization_241 (Batch  (None, None, None,   576        ['conv2d_244[0][0]']
#  Normalization)                 192)
#
#  batch_normalization_244 (Batch  (None, None, None,   576        ['conv2d_247[0][0]']
# ...
#  ooling2D)                      1280)
#
#  conv2d_280 (Conv2D)            (None, None, None,   409600      ['mixed8[0][0]']
#                                 320)
#
#  batch_normalization_279 (Batch  (None, None, None,   1152       ['conv2d_282[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_280 (Batch  (None, None, None,   1152       ['conv2d_283[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_283 (Batch  (None, None, None,   1152       ['conv2d_286[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_284 (Batch  (None, None, None,   1152       ['conv2d_287[0][0]']
#  Normalization)                 384)
#
#  conv2d_288 (Conv2D)            (None, None, None,   245760      ['average_pooling2d_25[0][0]']
#                                 192)
#
#  batch_normalization_277 (Batch  (None, None, None,   960        ['conv2d_280[0][0]']
#  Normalization)                 320)
#
#  activation_266 (Activation)    (None, None, None,   0           ['batch_normalization_279[0][0]']
#                                 384)
#
#  activation_267 (Activation)    (None, None, None,   0           ['batch_normalization_280[0][0]']
#                                 384)
#
#  activation_270 (Activation)    (None, None, None,   0           ['batch_normalization_283[0][0]']
#                                 384)
#
#  activation_271 (Activation)    (None, None, None,   0           ['batch_normalization_284[0][0]']
#                                 384)
#
#  batch_normalization_285 (Batch  (None, None, None,   576        ['conv2d_288[0][0]']
#  Normalization)                 192)
#
#  activation_264 (Activation)    (None, None, None,   0           ['batch_normalization_277[0][0]']
#                                 320)
#
#  mixed9_0 (Concatenate)         (None, None, None,   0           ['activation_266[0][0]',
#                                 768)                              'activation_267[0][0]']
#
#  concatenate_4 (Concatenate)    (None, None, None,   0           ['activation_270[0][0]',
#                                 768)                              'activation_271[0][0]']
#
#  activation_272 (Activation)    (None, None, None,   0           ['batch_normalization_285[0][0]']
#                                 192)
#
#  mixed9 (Concatenate)           (None, None, None,   0           ['activation_264[0][0]',
#                                 2048)                             'mixed9_0[0][0]',
#                                                                   'concatenate_4[0][0]',
#                                                                   'activation_272[0][0]']
#
#  conv2d_293 (Conv2D)            (None, None, None,   917504      ['mixed9[0][0]']
#                                 448)
#
#  batch_normalization_290 (Batch  (None, None, None,   1344       ['conv2d_293[0][0]']
#  Normalization)                 448)
#
#  activation_277 (Activation)    (None, None, None,   0           ['batch_normalization_290[0][0]']
#                                 448)
#
#  conv2d_290 (Conv2D)            (None, None, None,   786432      ['mixed9[0][0]']
#                                 384)
#
#  conv2d_294 (Conv2D)            (None, None, None,   1548288     ['activation_277[0][0]']
#                                 384)
#
#  batch_normalization_287 (Batch  (None, None, None,   1152       ['conv2d_290[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_291 (Batch  (None, None, None,   1152       ['conv2d_294[0][0]']
#  Normalization)                 384)
#
#  activation_274 (Activation)    (None, None, None,   0           ['batch_normalization_287[0][0]']
#                                 384)
#
#  activation_278 (Activation)    (None, None, None,   0           ['batch_normalization_291[0][0]']
#                                 384)
#
#  conv2d_291 (Conv2D)            (None, None, None,   442368      ['activation_274[0][0]']
#                                 384)
#
#  conv2d_292 (Conv2D)            (None, None, None,   442368      ['activation_274[0][0]']
#                                 384)
#
#  conv2d_295 (Conv2D)            (None, None, None,   442368      ['activation_278[0][0]']
#                                 384)
#
#  conv2d_296 (Conv2D)            (None, None, None,   442368      ['activation_278[0][0]']
#                                 384)
#
#  average_pooling2d_26 (AverageP  (None, None, None,   0          ['mixed9[0][0]']
#  ooling2D)                      2048)
#
#  conv2d_289 (Conv2D)            (None, None, None,   655360      ['mixed9[0][0]']
#                                 320)
#
#  batch_normalization_288 (Batch  (None, None, None,   1152       ['conv2d_291[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_289 (Batch  (None, None, None,   1152       ['conv2d_292[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_292 (Batch  (None, None, None,   1152       ['conv2d_295[0][0]']
#  Normalization)                 384)
#
#  batch_normalization_293 (Batch  (None, None, None,   1152       ['conv2d_296[0][0]']
#  Normalization)                 384)
#
#  conv2d_297 (Conv2D)            (None, None, None,   393216      ['average_pooling2d_26[0][0]']
#                                 192)
#
#  batch_normalization_286 (Batch  (None, None, None,   960        ['conv2d_289[0][0]']
#  Normalization)                 320)
#
#  activation_275 (Activation)    (None, None, None,   0           ['batch_normalization_288[0][0]']
#                                 384)
#
#  activation_276 (Activation)    (None, None, None,   0           ['batch_normalization_289[0][0]']
#                                 384)
#
#  activation_279 (Activation)    (None, None, None,   0           ['batch_normalization_292[0][0]']
#                                 384)
#
#  activation_280 (Activation)    (None, None, None,   0           ['batch_normalization_293[0][0]']
#                                 384)
#
#  batch_normalization_294 (Batch  (None, None, None,   576        ['conv2d_297[0][0]']
#  Normalization)                 192)
#
#  activation_273 (Activation)    (None, None, None,   0           ['batch_normalization_286[0][0]']
#                                 320)
#
#  mixed9_1 (Concatenate)         (None, None, None,   0           ['activation_275[0][0]',
#                                 768)                              'activation_276[0][0]']
#
#  concatenate_5 (Concatenate)    (None, None, None,   0           ['activation_279[0][0]',
#                                 768)                              'activation_280[0][0]']
#
#  activation_281 (Activation)    (None, None, None,   0           ['batch_normalization_294[0][0]']
#                                 192)
#
#  mixed10 (Concatenate)          (None, None, None,   0           ['activation_273[0][0]',
#                                 2048)                             'mixed9_1[0][0]',
#                                                                   'concatenate_5[0][0]',
#                                                                   'activation_281[0][0]']
#
#  global_average_pooling2d_4 (Gl  (None, 2048)        0           ['mixed10[0][0]']
#  obalAveragePooling2D)
#
#  dense_9 (Dense)                (None, 512)          1049088     ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  dense_10 (Dense)               (None, 5)            2565        ['dense_9[0][0]']
#
# ==================================================================================================
# Total params: 22,854,437
# Trainable params: 1,051,653
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
model_inception.compile(
    loss = keras.losses.SparseCategoricalCrossentropy(from_logits = True),
    optimizer = keras.optimizers.Adam(learning_rate = 0.001),
    metrics = ['accuracy'],
)

# %%
model_inception.fit(x, y, verbose = 2, batch_size = 64, epochs = 5)
# model_inception.evaluate(x_test, y_test, verbose = 2, batch_size = 64)
# Out:
# Epoch 1/5
# 1/1 - 4s - loss: 1.7155 - accuracy: 0.0000e+00 - 4s/epoch - 4s/step
# Epoch 2/5
# 1/1 - 0s - loss: 1.9325 - accuracy: 0.2000 - 53ms/epoch - 53ms/step
# Epoch 3/5
# 1/1 - 0s - loss: 1.1956 - accuracy: 0.4000 - 50ms/epoch - 50ms/step
# Epoch 4/5
# 1/1 - 0s - loss: 1.1429 - accuracy: 0.8000 - 51ms/epoch - 51ms/step
# Epoch 5/5
# 1/1 - 0s - loss: 1.1140 - accuracy: 0.6000 - 53ms/epoch - 53ms/step

# %%
# Using tensorflow hub models (Now integrated with Kaggle)
url = "https://www.kaggle.com/models/google/inception-v3/TensorFlow2/feature-vector/2"
feature_extractor = hub.KerasLayer(url, trainable=False, input_shape=(299, 299, 3))
feature_extractor.trainable = False
base_model_hub = Sequential([
    feature_extractor,
    layers.Dense(5),
])
print(base_model_hub.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer_3 (KerasLayer)  (None, 2048)              21802784
#
#  dense_12 (Dense)            (None, 5)                 10245
#
# =================================================================
# Total params: 21,813,029
# Trainable params: 10,245
# Non-trainable params: 21,802,784
# _________________________________________________________________
# None

# %%
base_model_hub.compile(
    loss = keras.losses.SparseCategoricalCrossentropy(from_logits = True),
    optimizer = keras.optimizers.Adam(learning_rate=0.001),
    metrics = ['accuracy'],
)

base_model_hub.fit(x, y, verbose=2, epochs = 5)
# Out:
# Epoch 1/5
# 1/1 - 6s - loss: 1.6733 - accuracy: 0.0000e+00 - 6s/epoch - 6s/step
# Epoch 2/5
# 1/1 - 0s - loss: 1.5842 - accuracy: 0.0000e+00 - 54ms/epoch - 54ms/step
# Epoch 3/5
# 1/1 - 0s - loss: 1.5279 - accuracy: 0.4000 - 51ms/epoch - 51ms/step
# Epoch 4/5
# 1/1 - 0s - loss: 1.4693 - accuracy: 0.6000 - 53ms/epoch - 53ms/step
# Epoch 5/5
# 1/1 - 0s - loss: 1.4036 - accuracy: 0.8000 - 55ms/epoch - 55ms/step
